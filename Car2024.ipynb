# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
df=pd.read_csv(r"C:\Users\Sathishwaran007\OneDrive\Documents\Project CSV\Car2024.csv")
df.head()
df.tail()
#Display top 10 rows of Dataset
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price   Dealer_No   \
# 23901          Overhead Camshaft       Manual         Red   12000  60504-7114
# 23902  DoubleÂ Overhead Camshaft         Auto       Black   16000  06457-3834
# 23903          Overhead Camshaft       Manual         Red   21000  99301-3882
# 23904  DoubleÂ Overhead Camshaft         Auto       Black   31000  53546-9427
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White   27500  38701-8047
#
#       Body Style    Phone Dealer_Region
# 23901  Passenger  8583598         Pasco
# 23902    Hardtop  7914229    Middletown
# 23903      Sedan  7659127    Scottsdale
# 23904  Passenger  6030764        Austin
# 23905    Hardtop  7020564    Middletown

# %%
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price   Dealer_No   \
# 23901          Overhead Camshaft       Manual         Red   12000  60504-7114
# 23902  DoubleÂ Overhead Camshaft         Auto       Black   16000  06457-3834
# 23903          Overhead Camshaft       Manual         Red   21000  99301-3882
# 23904  DoubleÂ Overhead Camshaft         Auto       Black   31000  53546-9427
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White   27500  38701-8047
#
#       Body Style    Phone Dealer_Region
# 23901  Passenger  8583598         Pasco
# 23902    Hardtop  7914229    Middletown
# 23903      Sedan  7659127    Scottsdale
# 23904  Passenger  6030764        Austin
# 23905    Hardtop  7020564    Middletown

# %%
df.shape
# Out:
# (23906, 16)

# %%
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price            0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
df['Customer Name'] = df['Customer Name'].fillna(mode_value)

# %%
df.columns = df.columns.str.strip()
df = df.drop(columns='Car_id', axis=1)  
df.columns
# Out:
# Index(['Date', 'Customer Name', 'Gender', 'Annual Income', 'Dealer_Name',
#        'Company', 'Model', 'Engine', 'Transmission', 'Color', 'Price',
#        'Dealer_No', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           23906 non-null  object
#  1   Customer Name  23906 non-null  object
#  2   Gender         23906 non-null  object
#  3   Annual Income  23906 non-null  int64
#  4   Dealer_Name    23906 non-null  object
#  5   Company        23906 non-null  object
#  6   Model          23906 non-null  object
#  7   Engine         23906 non-null  object
#  8   Transmission   23906 non-null  object
#  9   Color          23906 non-null  object
#  10  Price          23906 non-null  int64
#  11  Dealer_No      23906 non-null  object
#  12  Body Style     23906 non-null  object
#  13  Phone          23906 non-null  int64
#  14  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 2.7+ MB

# %%
df.columns = df.columns.str.strip()
df
# Out:
#              Date Customer Name  Gender  Annual Income  \
# 0      01-02-2022     Geraldine    Male          13500
# 1      01-02-2022           Gia    Male        1480000
# 2      01-02-2022        Gianna    Male        1035000
# 3      01-02-2022       Giselle    Male          13500
# 4      01-02-2022         Grace    Male        1465000
# ...           ...           ...     ...            ...
# 23901  12/31/2023        Martin    Male          13500
# 23902  12/31/2023         Jimmy  Female         900000
# 23903  12/31/2023          Emma    Male         705000
# 23904  12/31/2023      Victoire    Male          13500
# 23905  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                           Engine Transmission       Color  Price   Dealer_No  \
# 0      DoubleÂ Overhead Camshaft         Auto       Black  26000  06457-3834
# 1      DoubleÂ Overhead Camshaft         Auto       Black  19000  60504-7114
# 2              Overhead Camshaft       Manual         Red  31500  38701-8047
# 3              Overhead Camshaft       Manual  Pale White  14000  99301-3882
# 4      DoubleÂ Overhead Camshaft         Auto         Red  24500  53546-9427
# ...                          ...          ...         ...    ...         ...
# 23901          Overhead Camshaft       Manual         Red  12000  60504-7114
# 23902  DoubleÂ Overhead Camshaft         Auto       Black  16000  06457-3834
# 23903          Overhead Camshaft       Manual         Red  21000  99301-3882
# 23904  DoubleÂ Overhead Camshaft         Auto       Black  31000  53546-9427
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White  27500  38701-8047
#
#       Body Style    Phone Dealer_Region
# 0            SUV  8264678    Middletown
# 1            SUV  6848189        Aurora
# 2      Passenger  7298798    Greenville
# 3            SUV  6257557         Pasco
# 4      Hatchback  7081483    Janesville
# ...          ...      ...           ...
# 23901  Passenger  8583598         Pasco
# 23902    Hardtop  7914229    Middletown
# 23903      Sedan  7659127    Scottsdale
# 23904  Passenger  6030764        Austin
# 23905    Hardtop  7020564    Middletown
#
# [23906 rows x 15 columns]

# %%
df.describe()
# Out:
#        Annual Income         Price         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df['Price']
# Out:
# 0        26000
# 1        19000
# 2        31500
# 3        14000
# 4        24500
#          ...
# 23901    12000
# 23902    16000
# 23903    21000
# 23904    31000
# 23905    27500
# Name: Price, Length: 23906, dtype: int64

# %%
df['Gender'].value_counts()
#Which gender has purchased more cars
# Out:
# Gender
# Male      18798
# Female     5108
# Name: count, dtype: int64

# %%
# Plot the count of car purchases by gender
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df, palette='viridis')

# Customize the plot
plt.title('Number of Car Purchases by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Purchases')

plt.show()
# Out:
# C:\Users\Sathishwaran007\AppData\Local\Temp\ipykernel_10068\4135919134.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df['Company'].value_counts()
#Number of cars Sold in each brands
# Out:
# Company
# Chevrolet     1819
# Dodge         1671
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Mercury        874
# Lexus          802
# Pontiac        796
# BMW            790
# Volvo          789
# Honda          708
# Acura          689
# Cadillac       652
# Plymouth       617
# Saturn         586
# Lincoln        492
# Audi           468
# Buick          439
# Subaru         405
# Jeep           363
# Porsche        361
# Hyundai        264
# Saab           210
# Infiniti       195
# Jaguar         180
# Name: count, dtype: int64

# %% [markdown]
# **How many numbers are sold in each Brand**

# %%
data = {
    'Company': ['Chevrolet', 'Dodge', 'Ford', 'Volkswagen', 'Mercedes-B', 'Mitsubishi', 'Chrysler', 
                'Oldsmobile', 'Toyota', 'Nissan', 'Mercury', 'Lexus', 'Pontiac', 'BMW', 'Volvo', 'Honda', 
                'Acura', 'Cadillac', 'Plymouth', 'Saturn', 'Lincoln', 'Audi', 'Buick', 'Subaru', 'Hyundai', 
                'Saab', 'Infiniti', 'Jaguar'],
    'Value': [1819, 1670, 1614, 1333, 1285, 1277, 1120, 1111, 1110, 886, 874, 802, 796, 790, 789, 708, 
              689, 652, 617, 586, 492, 468, 439, 405, 264, 210, 195, 180]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create the bar chart
fig = px.bar(df, x='Company', y='Value', 
             title="Car Companies and Their Sales", 
             labels={'Company': 'Car Company', 'Value': 'Sales Value'}, 
             color='Value', 
             color_continuous_scale='Viridis')

# Update the layout for title and x-axis labels
fig.update_layout(
    title="Car Brands and Their Sales",  # Updated title text
    title_font_size=24,                  # Title font size
    title_x=0.5,                         # Center-align title
    xaxis_tickangle=-45,                 # Rotate x-axis labels for readability
    yaxis=dict(
        range=[0, 2000]  # Manually set the y-axis range
    )
)

# Add annotations for sales values on top of each bar
for i, row in df.iterrows():
    fig.add_annotation(
        x=row['Company'],
        y=row['Value'],
        text=str(row['Value']),
        showarrow=False,
        yshift=10  # Shift text above the bar
    )

fig.show()

# %%
df.columns
# Out:
# Index(['Date', 'Customer Name', 'Gender', 'Annual Income', 'Dealer_Name',
#        'Company', 'Model', 'Engine', 'Transmission', 'Color', 'Price',
#        'Dealer_No', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
df['Company'].value_counts()
#Number of cars Sold in each brands
# Out:
# Company
# Chevrolet     1819
# Dodge         1671
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Mercury        874
# Lexus          802
# Pontiac        796
# BMW            790
# Volvo          789
# Honda          708
# Acura          689
# Cadillac       652
# Plymouth       617
# Saturn         586
# Lincoln        492
# Audi           468
# Buick          439
# Subaru         405
# Jeep           363
# Porsche        361
# Hyundai        264
# Saab           210
# Infiniti       195
# Jaguar         180
# Name: count, dtype: int64

# %%
df['Price'].mean()
#Average
# Out:
# np.float64(28090.247845729107)

# %%
df['Price'].max()
#Highest price
# Out:
# np.int64(85800)

# %%
df['Price'].min()
#Lowest price
# Out:
# np.int64(1200)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23905 entries, 0 to 23905
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           23905 non-null  object
#  1   Customer Name  23905 non-null  object
#  2   Gender         23905 non-null  object
#  3   Annual Income  23905 non-null  int64
#  4   Dealer_Name    23905 non-null  object
#  5   Company        23905 non-null  object
#  6   Model          23905 non-null  object
#  7   Engine         23905 non-null  object
#  8   Transmission   23905 non-null  object
#  9   Color          23905 non-null  object
#  10  Price          23905 non-null  int64
#  11  Dealer_No      23905 non-null  object
#  12  Body Style     23905 non-null  object
#  13  Phone          23905 non-null  int64
#  14  Dealer_Region  23905 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 2.9+ MB

# %%
df['Engine'].value_counts()
#which engine sold high
# Out:
# Engine
# DoubleÂ Overhead Camshaft    12571
# Overhead Camshaft            11335
# Name: count, dtype: int64

# %%
# Create a DataFrame with the Engine counts
engine_counts = df['Engine'].value_counts().reset_index()
engine_counts.columns = ['Engine', 'Count']

# Plot the bar chart
fig = px.bar(engine_counts, x='Engine', y='Count', title="Engine Types Count",
            labels={'Engine': 'Engine Type', 'Count': 'Number of Cars'}, 
            color='Count', color_continuous_scale='Viridis')

# Show the plot
fig.show()

# %%
df['Transmission'].value_counts()
#which transmission people likes to use most
# Out:
# Transmission
# Auto      12570
# Manual    11335
# Name: count, dtype: int64

# %%
# Create a DataFrame with the Engine counts
engine_counts = df['Transmission'].value_counts().reset_index()
engine_counts.columns = ['Transmissione', 'Count']

# Plot the bar chart
fig = px.bar(engine_counts, x='Transmissione', y='Count', title="Transmission Types Count",
            labels={'Transmissione': 'Transmission Type', 'Count': 'Number of Cars'}, 
            color='Count', color_continuous_scale='Viridis')


fig.show()

# %%
df['Body Style'].value_counts()
#Which Body style of cars customer like to buy the most
# Out:
# Body Style
# SUV          6373
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2971
# Name: count, dtype: int64

# %%
# Create a DataFrame with the Body Style counts
body_style_counts = df['Body Style'].value_counts().reset_index()
body_style_counts.columns = ['Body Style', 'Count']

# Plot the bar chart
fig = px.bar(body_style_counts, x='Body Style', y='Count', title="Body Style Types Count",
            labels={'Body Style': 'Body Style', 'Count': 'Number of Cars'}, 
            color='Count', color_continuous_scale='Viridis')


fig.show()

# %%
df['Model'].value_counts()
#Which model has sold high
# Out:
# Model
# Diamante         418
# Silhouette       411
# Prizm            411
# Passat           391
# Ram Pickup       383
#                 ...
# Mirage            19
# Alero             18
# RX300             15
# Avalon            15
# Sebring Conv.     10
# Name: count, Length: 154, dtype: int64

# %%
# Create a DataFrame with the Body Style counts
body_style_counts = df['Model'].value_counts().reset_index()
body_style_counts.columns = ['Body Style', 'Count']

# Plot the bar chart
fig = px.bar(body_style_counts, x='Body Style', y='Count', title="Body Style Types Count",
            labels={'Body Style': 'Body Style', 'Count': 'Number of Cars'}, 
            color='Count', color_continuous_scale='Viridis')


fig.show()

# %%
# Get the top 10 most frequent models
top_models = df['Model'].value_counts().head(10).reset_index()
top_models.columns = ['Model', 'Count']

# Plot the bar chart
fig = px.bar(top_models, x='Model', y='Count', title="Top 10 Car Models Sold",
            labels={'Model': 'Car Model', 'Count': 'Number of Cars'},
            color='Count', color_continuous_scale='Viridis')

# Show the plot
fig.show()

# %%
df['Dealer_Region'].value_counts()
#Regionwise car sales
# Out:
# Dealer_Region
# Austin        4135
# Janesville    3821
# Scottsdale    3433
# Pasco         3131
# Aurora        3129
# Middletown    3128
# Greenville    3128
# Name: count, dtype: int64

# %%
# Get sales count by Dealer Region
region_sales = df['Dealer_Region'].value_counts()

# Plot Bar chart
fig = px.bar(region_sales, 
             x=region_sales.index, 
             y=region_sales.values, 
             labels={'x': 'Dealer Region', 'y': 'Number of Sales'},
             title='Sales Distribution by Dealer Region')

fig.show()

# %%
df['Color'].value_counts()
#Which color cars have been sold in high number
# Out:
# Color
# Pale White    11256
# Black          7856
# Red            4793
# Name: count, dtype: int64

# %%
# Get the value counts for 'Color'
color_counts = df['Color'].value_counts()

# Create a pie chart using the value counts of 'Color'
fig = px.pie(names=color_counts.index, values=color_counts.values, title='Car Color Distribution')


fig.show()

# %%
df['Date'].value_counts()
# Out:
# Date
# 09-05-2023    190
# 11-10-2023    175
# 12/29/2023    151
# 12-11-2023    140
# 11/24/2023    135
#              ...
# 05-11-2022      5
# 10/16/2023      5
# 10/19/2023      5
# 10/18/2023      5
# 01-10-2022      5
# Name: count, Length: 612, dtype: int64

# %%
# Get the value counts for 'Date'
date_counts = df['Date'].value_counts().sort_index()

# Create a bar chart using the value counts of 'Date'
fig = px.bar(x=date_counts.index, y=date_counts.values, title='Count of Sales per Date')

# Update layout for readability
fig.update_layout(xaxis_title='Date', yaxis_title='Count', xaxis_tickangle=-45)


fig.show()

# %%
df.describe()
# Out:
#        Annual Income         Price         Phone
# count   2.390500e+04  23905.000000  2.390500e+04
# mean    8.308131e+05  28090.628111  7.497768e+06
# std     7.200092e+05  14788.880062  8.675000e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746465e+06
# 50%     7.350000e+05  23000.000000  7.496199e+06
# 75%     1.175000e+06  34000.000000  8.248172e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
df.describe(include='all')
# Out:
#               Date Customer Name Gender  Annual Income  \
# count        23905         23905  23905   2.390500e+04
# unique         612          3021      2            NaN
# top     09-05-2023        Thomas   Male            NaN
# freq           190            93  18797            NaN
# mean           NaN           NaN    NaN   8.308131e+05
# std            NaN           NaN    NaN   7.200092e+05
# min            NaN           NaN    NaN   1.008000e+04
# 25%            NaN           NaN    NaN   3.860000e+05
# 50%            NaN           NaN    NaN   7.350000e+05
# 75%            NaN           NaN    NaN   1.175000e+06
# max            NaN           NaN    NaN   1.120000e+07
#
#                                             Dealer_Name    Company     Model  \
# count                                             23905      23905     23905
# unique                                               28         30       154
# top     Progressive Shippers Cooperative Association No  Chevrolet  Diamante
# freq                                               1318       1819       418
# mean                                                NaN        NaN       NaN
# std                                                 NaN        NaN       NaN
# min                                                 NaN        NaN       NaN
# 25%                                                 NaN        NaN       NaN
# 50%                                                 NaN        NaN       NaN
# 75%                                                 NaN        NaN       NaN
# max                                                 NaN        NaN       NaN
#
#                            Engine Transmission       Color         Price  \
# count                       23905        23905       23905  23905.000000
# unique                          2            2           3           NaN
# top     DoubleÂ Overhead Camshaft         Auto  Pale White           NaN
# freq                        12570        12570       11256           NaN
# mean                          NaN          NaN         NaN  28090.628111
# std                           NaN          NaN         NaN  14788.880062
# min                           NaN          NaN         NaN   1200.000000
# 25%                           NaN          NaN         NaN  18001.000000
# 50%                           NaN          NaN         NaN  23000.000000
# 75%                           NaN          NaN         NaN  34000.000000
# max                           NaN          NaN         NaN  85800.000000
#
#          Dealer_No Body Style         Phone Dealer_Region
# count        23905      23905  2.390500e+04         23905
# unique           7          5           NaN             7
# top     85257-3102        SUV           NaN        Austin
# freq          3814       6373           NaN          4135
# mean           NaN        NaN  7.497768e+06           NaN
# std            NaN        NaN  8.675000e+05           NaN
# min            NaN        NaN  6.000101e+06           NaN
# 25%            NaN        NaN  6.746465e+06           NaN
# 50%            NaN        NaN  7.496199e+06           NaN
# 75%            NaN        NaN  8.248172e+06           NaN
# max            NaN        NaN  8.999579e+06           NaN

# %%
df['Customer Name'].value_counts()
#customers with same names
# Out:
# Customer Name
# Thomas           92
# Emma             90
# Lucas            88
# Nathan           80
# Louis            76
#                  ..
# Adelin            1
# Zakarya           1
# Paule             1
# Noeline           1
# Djamel Epoine     1
# Name: count, Length: 3021, dtype: int64

# %%
import plotly.express as px

# Get the top 10 most frequent customer names
customer_counts = df['Customer Name'].value_counts().head(10)

# Create a bar chart
fig = px.bar(customer_counts, 
             x=customer_counts.index, 
             y=customer_counts.values, 
             labels={'x': 'Customer Name', 'y': 'Frequency'}, 
             title='Top 10 Most Frequent Customer Names')

# Show the plot
fig.show()

# %%
df['Customer Name'].value_counts().head()
# Out:
# Customer Name
# Thomas    92
# Emma      90
# Lucas     88
# Nathan    80
# Louis     76
# Name: count, dtype: int64

# %%
df['Model'].nunique()
# Out:
# 154

# %%
date_col = pd.DatetimeIndex(df['Date'])
df['Year'] = date_col.year
#adding year to see yearwise data

# %%
df
# Out:
#              Date Customer Name  Gender  Annual Income  \
# 0      01-02-2022     Geraldine    Male          13500
# 2      01-02-2022        Gianna    Male        1035000
# 3      01-02-2022       Giselle    Male          13500
# 4      01-02-2022         Grace    Male        1465000
# 5      01-02-2022     Guadalupe    Male         850000
# ...           ...           ...     ...            ...
# 23901  12/31/2023        Martin    Male          13500
# 23902  12/31/2023         Jimmy  Female         900000
# 23903  12/31/2023          Emma    Male         705000
# 23904  12/31/2023      Victoire    Male          13500
# 23905  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name     Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc        Ford  Expedition
# 2                              Capitol KIA    Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities      Toyota      Celica
# 4                        Chrysler Plymouth       Acura          TL
# 5                            Classic Chevy  Mitsubishi    Diamante
# ...                                    ...         ...         ...
# 23901                     C & M Motors Inc    Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing   Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities         BMW        328i
# 23904                    Chrysler Plymouth   Chevrolet       Metro
# 23905                      Pars Auto Sales       Lexus       ES300
#
#                           Engine Transmission       Color  Price  Dealer_No   \
# 0      DoubleÂ Overhead Camshaft         Auto       Black  26000  06457-3834
# 2              Overhead Camshaft       Manual         Red  31500  38701-8047
# 3              Overhead Camshaft       Manual  Pale White  14000  99301-3882
# 4      DoubleÂ Overhead Camshaft         Auto         Red  24500  53546-9427
# 5              Overhead Camshaft       Manual  Pale White  12000  85257-3102
# ...                          ...          ...         ...    ...         ...
# 23901          Overhead Camshaft       Manual         Red  12000  60504-7114
# 23902  DoubleÂ Overhead Camshaft         Auto       Black  16000  06457-3834
# 23903          Overhead Camshaft       Manual         Red  21000  99301-3882
# 23904  DoubleÂ Overhead Camshaft         Auto       Black  31000  53546-9427
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White  27500  38701-8047
#
#       Body Style    Phone Dealer_Region  Year
# 0            SUV  8264678    Middletown  2022
# 2      Passenger  7298798    Greenville  2022
# 3            SUV  6257557         Pasco  2022
# 4      Hatchback  7081483    Janesville  2022
# 5      Hatchback  7315216    Scottsdale  2022
# ...          ...      ...           ...   ...
# 23901  Passenger  8583598         Pasco  2023
# 23902    Hardtop  7914229    Middletown  2023
# 23903      Sedan  7659127    Scottsdale  2023
# 23904  Passenger  6030764        Austin  2023
# 23905    Hardtop  7020564    Middletown  2023
#
# [23905 rows x 16 columns]

# %%
df['Year'].value_counts()
#Sales by yearwise
# Out:
# Year
# 2023    13261
# 2022    10644
# Name: count, dtype: int64

# %%
df.groupby(['Year'])['Price'].sum()
total_sales_yearwise = df.groupby(['Year'])['Price'].sum()
#Total sales yearwise by $

# %%
# Create a line chart for total sales year-wise
fig = px.line(total_sales_yearwise, 
              x=total_sales_yearwise.index, 
              y=total_sales_yearwise.values, 
              labels={'x': 'Year', 'y': 'Total Sales ($)'},
              title='Total Sales Yearwise in Dollars')

fig.show()

# %%
df.Price.sum()
#Over all sales in Dataset $
# Out:
# 671506465

# %%
company_sales = df.groupby(['Company'])['Price'].sum().sort_values(ascending=False)
#Highest sales Brandwise+Price

company_sales
# Out:
# Company
# Chevrolet     47655265
# Ford          47231583
# Dodge         44124996
# Oldsmobile    35434512
# Mercedes-B    34624123
# Volkswagen    34082881
# Mitsubishi    34062466
# Toyota        32759564
# Chrysler      29141873
# Lexus         27287703
# Cadillac      26713805
# Mercury       24939733
# Nissan        23964095
# Pontiac       23369207
# Volvo         21925200
# Honda         19882735
# BMW           19821592
# Saturn        18220269
# Plymouth      18142873
# Acura         17058649
# Lincoln       15452262
# Buick         14765485
# Subaru        11312193
# Audi          10694638
# Porsche        8185637
# Saab           7668431
# Jeep           7643814
# Infiniti       5717040
# Hyundai        5117966
# Jaguar         4524875
# Name: Price, dtype: int64

# %%
# Plotting a bar chart for sales by company
fig = px.bar(company_sales, 
             x=company_sales.index, 
             y=company_sales.values, 
             labels={'x': 'Company', 'y': 'Total Sales ($)'}, 
             title='Total Sales by Company 2022 - 2023')

fig.show()

# %%
df.groupby(['Company'])['Price'].sum().sort_values(ascending=False).head()
#Highest sales Brandwise+Price Top 5
# Out:
# Company
# Chevrolet     47655265
# Ford          47231583
# Dodge         44124996
# Oldsmobile    35434512
# Mercedes-B    34624123
# Name: Price, dtype: int64

# %%
# Assuming company_sales is a pandas Series or DataFrame with company names as index
top_5_sales = company_sales.nlargest(5)  # Get the top 5 companies by sales

# Plotting a bar chart for top 5 sales by company
fig = px.bar(top_5_sales, 
             x=top_5_sales.index, 
             y=top_5_sales.values, 
             labels={'x': 'Company', 'y': 'Total Sales ($)'}, 
             title='Top 5 Companies by Total Sales 2022 - 2023')

fig.show()

# %%
df.groupby(['Company'])['Price'].sum().sort_values(ascending=False).tail()
#Least sales Brandwise+Price, Least 5
# Out:
# Company
# Saab        7668431
# Jeep        7643814
# Infiniti    5717040
# Hyundai     5117966
# Jaguar      4524875
# Name: Price, dtype: int64

# %%
company_model_counts = df.groupby(['Company'])['Model'].value_counts()
#Brand & Models sales data
company_model_counts
# Out:
# Company  Model
# Acura    RL         372
#          TL         269
#          Integra     48
# Audi     A6         329
#          A4         102
#                    ...
# Volvo    C70        210
#          S70        148
#          S80         86
#          V70         41
#          V40         22
# Name: count, Length: 155, dtype: int64

# %%
import plotly.express as px

# Reset index to make 'Company' and 'Model' columns for plotting
company_model_counts_reset = company_model_counts.reset_index(name='Count')

# Plotting a bar chart for model counts by company
fig = px.bar(company_model_counts_reset, 
             x='Company', 
             y='Count', 
             color='Model', 
             title='Model Count by Company',
             labels={'Company': 'Company', 'Count': 'Model Count'})

fig.show()

# %%
df['Company'].value_counts()
#Which brand as sold highest number of Cars
# Out:
# Company
# Chevrolet     1819
# Dodge         1670
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Mercury        874
# Lexus          802
# Pontiac        796
# BMW            790
# Volvo          789
# Honda          708
# Acura          689
# Cadillac       652
# Plymouth       617
# Saturn         586
# Lincoln        492
# Audi           468
# Buick          439
# Subaru         405
# Jeep           363
# Porsche        361
# Hyundai        264
# Saab           210
# Infiniti       195
# Jaguar         180
# Name: count, dtype: int64

# %%
df['Company'].value_counts().head(10)
#Brands sold highest- Top 10
# Out:
# Company
# Chevrolet     1819
# Dodge         1670
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Name: count, dtype: int64

# %%
df['Company'].value_counts().tail(10)
#Brands sold Least- Least 10
# Out:
# Company
# Lincoln     492
# Audi        468
# Buick       439
# Subaru      405
# Jeep        363
# Porsche     361
# Hyundai     264
# Saab        210
# Infiniti    195
# Jaguar      180
# Name: count, dtype: int64

# %%
df['Dealer_Name'].value_counts()
#Which dealer has given high sales
# Out:
# Dealer_Name
# Progressive Shippers Cooperative Association No    1318
# Rabun Used Car Sales                               1313
# Race Car Help                                      1253
# Saab-Belle Dodge                                   1251
# Star Enterprises Inc                               1249
# Tri-State Mack Inc                                 1249
# Ryder Truck Rental and Leasing                     1248
# U-Haul CO                                          1247
# Scrivener Performance Engineering                  1246
# Suburban Ford                                      1243
# Nebo Chevrolet                                      633
# Pars Auto Sales                                     630
# New Castle Ford Lincoln Mercury                     629
# McKinney Dodge Chrysler Jeep                        629
# Hatfield Volkswagen                                 629
# Gartner Buick Hyundai Saab                          628
# Pitre Buick-Pontiac-Gmc of Scottsdale               628
# Capitol KIA                                         628
# Clay Johnson Auto Sales                             627
# Iceberg Rentals                                     627
# Buddy Storbeck's Diesel Service Inc                 627
# Motor Vehicle Branch Office                         626
# Chrysler of Tri-Cities                              626
# C & M Motors Inc                                    625
# Enterprise Rent A Car                               625
# Chrysler Plymouth                                   625
# Diehl Motor CO Inc                                  624
# Classic Chevy                                       623
# Name: count, dtype: int64

# %%
top_10_dealers = df['Dealer_Name'].value_counts().head(10)
#Dealerwise sales data only Top 10

# %%
# Get the top 10 dealers
top_10_dealers = df['Dealer_Name'].value_counts().head(10)

# Create a bar plot with seaborn
plt.figure(figsize=(10, 6))  # Set the figure size
sns.barplot(x=top_10_dealers.values, y=top_10_dealers.index, palette='Blues_d')

# Add labels and title
plt.title('Top 10 Dealers by Count')
plt.xlabel('Number of Records')
plt.ylabel('Dealer Name')

# Show the plot
plt.show()
# Out:
# C:\Users\Sathishwaran007\AppData\Local\Temp\ipykernel_9668\2759567017.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
df['Company'].value_counts().plot(kind = 'barh')
#Highest sold car Brand[Data visualizing]
# Out:
# <Axes: ylabel='Company'>

# %%
df.groupby(['Company'])['Price'].sum().plot(kind = 'bar')
#Highest sales Brandwise+Price $ +Data visualizing
# Out:
# <Axes: xlabel='Company'>

# %%
df.groupby(['Company'])['Price'].sum().head(10).plot.pie(y='Price',figsize=(10,6))
#Highest sales Brandwise+Price in $ +Data visualizing
# Out:
# <Axes: ylabel='Price'>

# %%
df.columns
# Out:
# Index(['Date', 'Customer Name', 'Gender', 'Annual Income', 'Dealer_Name',
#        'Company', 'Model', 'Engine', 'Transmission', 'Color', 'Price',
#        'Dealer_No', 'Body Style', 'Phone', 'Dealer_Region', 'Year'],
#       dtype='object')

# %%
df[df['Model'] == 'Diamante']
# Out:
#             Date Customer Name  Gender  Annual Income  \
# 5     2022-01-02     Guadalupe    Male         850000
# 69    2022-01-04          Toby    Male          13500
# 116   2022-01-09          Jake    Male         700000
# 158   2022-01-12        Romain    Male        2750000
# 185          NaT         Jayla    Male         890000
# ...          ...           ...     ...            ...
# 23555        NaT         Paige    Male          13500
# 23647        NaT         Devin  Female         344700
# 23682        NaT        Efraim  Female         390000
# 23810        NaT         Louis    Male        1615000
# 23813        NaT      Amandine    Male          13500
#
#                                Dealer_Name     Company     Model  \
# 5                            Classic Chevy  Mitsubishi  Diamante
# 69                 Clay Johnson Auto Sales  Mitsubishi  Diamante
# 116            Motor Vehicle Branch Office  Mitsubishi  Diamante
# 158                        Pars Auto Sales  Mitsubishi  Diamante
# 185             Gartner Buick Hyundai Saab  Mitsubishi  Diamante
# ...                                    ...         ...       ...
# 23555       Ryder Truck Rental and Leasing  Mitsubishi  Diamante
# 23647    Scrivener Performance Engineering  Mitsubishi  Diamante
# 23682                          Capitol KIA  Mitsubishi  Diamante
# 23810  Buddy Storbeck's Diesel Service Inc  Mitsubishi  Diamante
# 23813               Chrysler of Tri-Cities  Mitsubishi  Diamante
#
#                           Engine Transmission       Color  Price   Dealer_No  \
# 5              Overhead Camshaft       Manual  Pale White  12000  85257-3102
# 69     DoubleÂ Overhead Camshaft         Auto  Pale White  21000  78758-7841
# 116            Overhead Camshaft       Manual       Black  49000  78758-7841
# 158    DoubleÂ Overhead Camshaft         Auto       Black  18000  38701-8047
# 185            Overhead Camshaft       Manual  Pale White  19000  38701-8047
# ...                          ...          ...         ...    ...         ...
# 23555          Overhead Camshaft       Manual       Black  22000  06457-3834
# 23647  DoubleÂ Overhead Camshaft         Auto  Pale White  21700  38701-8047
# 23682  DoubleÂ Overhead Camshaft         Auto       Black  18000  38701-8047
# 23810  DoubleÂ Overhead Camshaft         Auto       Black  17500  06457-3834
# 23813  DoubleÂ Overhead Camshaft         Auto       Black  17000  99301-3882
#
#       Body Style    Phone Dealer_Region    Year
# 5      Hatchback  7315216    Scottsdale  2022.0
# 69     Hatchback  8822935         Pasco  2022.0
# 116    Hatchback  7757499        Austin  2022.0
# 158    Hatchback  6735346    Greenville  2022.0
# 185    Hatchback  7658357    Greenville     NaN
# ...          ...      ...           ...     ...
# 23555  Hatchback  6127554    Middletown     NaN
# 23647  Hatchback  6302535    Greenville     NaN
# 23682  Hatchback  6376938    Greenville     NaN
# 23810  Hatchback  6150391    Greenville     NaN
# 23813  Hatchback  6287723    Scottsdale     NaN
#
# [418 rows x 16 columns]

# %%
# Correlation between Annual Income and Price
correlation = df['Annual Income'].corr(df['Price'])
print(f"Correlation between Annual Income and Price: {correlation}")

# Scatter plot to visualize the relationship
sns.scatterplot(x='Annual Income', y='Price', data=df)
plt.title('Annual Income vs Car Price')
plt.show()
# Out:
# Correlation between Annual Income and Price: 0.012064959420296466

# %%
# Average Annual Income by Gender
income_by_gender = df.groupby('Gender')['Annual Income'].mean()
print(income_by_gender)
# Out:
# Gender
# Female    755973.021339
# Male      851184.044207
# Name: Annual Income, dtype: float64

# %%
# Bar plot to compare average Annual Income by Gender
sns.barplot(x='Gender', y='Annual Income', data=df)
plt.title('Average Annual Income by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Annual Income')
plt.show()

# %% [markdown]
# Model/Company Preference Based on Income

# %%
# Average Annual Income by Car Model
income_by_model = df.groupby('Model')['Annual Income'].mean().sort_values(ascending=False)
print(income_by_model)

# Average Annual Income by Company
income_by_company = df.groupby('Company')['Annual Income'].mean().sort_values(ascending=False)
print(income_by_company)
# Out:
# Model
# Sebring Conv.     1.196270e+06
# Accent            1.017677e+06
# Celica            1.010119e+06
# 05-Sep            1.006603e+06
# Carrera Cabrio    9.945521e+05
#                       ...
# RX300             6.718667e+05
# Cirrus            6.663378e+05
# Avalon            6.652000e+05
# Mirage            6.365000e+05
# Integra           6.270688e+05
# Name: Annual Income, Length: 154, dtype: float64
# Company
# Cadillac      913476.457055
# Hyundai       894106.772727
# Saab          892487.771429
# Mercury       890657.229977
# Toyota        876490.990090
# Nissan        863774.747178
# Infiniti      861800.923077
# Buick         855929.840547
# Volkswagen    854321.878470
# Porsche       853423.822715
# Volvo         837570.499366
# Plymouth      834670.745543
# Dodge         834585.241771
# Mitsubishi    833272.748630
# Chrysler      833011.186607
# BMW           831186.075949
# Oldsmobile    830651.319532
# Mercedes-B    823098.915953
# Audi          819655.626068
# Saturn        816950.767918
# Jeep          814149.966942
# Ford          813954.126394
# Acura         810430.190131
# Chevrolet     799263.693238
# Subaru        795085.550617
# Lincoln       794274.695122
# Pontiac       790448.979899
# Honda         778164.860169
# Lexus         776040.334165
# Jaguar        732528.544444
# Name: Annual Income, dtype: float64

# %%
# Get the top 10 car models with the highest average income
top_n = 10
income_by_model = df.groupby('Model')['Annual Income'].mean().sort_values(ascending=False).head(top_n)

# Plot the top N car models
income_by_model.plot(kind='bar', figsize=(10,6))
plt.title('Top 10 Car Models by Average Annual Income')
plt.xlabel('Car Model')
plt.ylabel('Average Annual Income')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Average Annual Income by Dealer Region
income_by_region = df.groupby('Dealer_Region')['Annual Income'].mean().sort_values(ascending=False)
print(income_by_region)
# Out:
# Dealer_Region
# Pasco         853975.290323
# Aurora        845510.435783
# Janesville    833916.268778
# Greenville    832667.512788
# Middletown    825592.651854
# Austin        822849.572189
# Scottsdale    805682.702884
# Name: Annual Income, dtype: float64

# %%
# Bar plot to compare average Annual Income by Dealer Region
income_by_region = df.groupby('Dealer_Region')['Annual Income'].mean().sort_values(ascending=False)
income_by_region.plot(kind='bar', figsize=(10,6))
plt.title('Average Annual Income by Dealer Region')
plt.xlabel('Dealer Region')
plt.ylabel('Average Annual Income')
plt.show()

# %%
# Average Annual Income by Body Style
income_by_body_style = df.groupby('Body Style')['Annual Income'].mean().sort_values(ascending=False)
print(income_by_body_style)
# Out:
# Body Style
# Hatchback    851174.051893
# Sedan        829198.641711
# SUV          823367.551773
# Hardtop      821333.736116
# Passenger    820355.502408
# Name: Annual Income, dtype: float64

# %%
# Bar plot to compare average Annual Income by Body Style
income_by_body_style = df.groupby('Body Style')['Annual Income'].mean().sort_values(ascending=False)
income_by_body_style.plot(kind='bar', figsize=(10,6))
plt.title('Average Annual Income by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Annual Income')
plt.show()

# %%
# Average Annual Income by Transmission type
income_by_transmission = df.groupby('Transmission')['Annual Income'].mean()
print(income_by_transmission)

# Average Annual Income by Engine type
income_by_engine = df.groupby('Engine')['Annual Income'].mean()
print(income_by_engine)
# Out:
# Transmission
# Auto      835351.185745
# Manual    825837.503308
# Name: Annual Income, dtype: float64
# Engine
# DoubleÂ Overhead Camshaft    835351.185745
# Overhead Camshaft            825837.503308
# Name: Annual Income, dtype: float64

# %%
# Bar plot to compare average Annual Income by Transmission type
income_by_transmission = df.groupby('Transmission')['Annual Income'].mean()
income_by_transmission.plot(kind='bar', figsize=(6,4))
plt.title('Average Annual Income by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Average Annual Income')
plt.show()

# %%
sns.histplot(df['Price'], kde=True)  # Distribution of 'Price'
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
# Create a strip plot for price distribution by car model
plt.figure(figsize=(10, 6))
sns.stripplot(x='Model', y='Price', data=df, jitter=True, palette='Set2')

# Add title and labels
plt.title('Price Distribution by Car Model (Strip Plot)', fontsize=16)
plt.xlabel('Car Model', fontsize=12)
plt.ylabel('Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sathishwaran007\AppData\Local\Temp\ipykernel_9668\1185598573.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Thanks...
